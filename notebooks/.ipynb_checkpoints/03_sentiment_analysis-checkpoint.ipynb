# %%
import sys
sys.path.append("../src")

# %%
from load_data import load_meetings

df = load_meetings("../data/raw")

# %%
from sentiment import sentiment_summary

sentiment_summary(df)
# Out:
# {'average_sentiment': np.float64(3.4160000000000004),
#  'max_sentiment': np.float64(4.9),
#  'min_sentiment': np.float64(1.4)}

# %%
from visualization import plot_sentiment_distribution

plot_sentiment_distribution(df)

# %%
df.groupby("overall_sentiment").size()
# Out:
# overall_sentiment
# mixed-negative    33
# mixed-positive    33
# negative           4
# positive           7
# very-negative      2
# very-positive     21
# dtype: int64

# %%
avg_by_sentiment = (
    df.groupby("overall_sentiment")["duration"]
    .mean()
)

avg_by_sentiment
# Out:
# overall_sentiment
# mixed-negative    26.051515
# mixed-positive    31.557576
# negative          27.100000
# positive          34.300000
# very-negative     15.550000
# very-positive     35.723810
# Name: duration, dtype: float64

# %%
avg_by_sentiment.plot(kind="bar")
# Out:
# <Axes: xlabel='overall_sentiment'>
